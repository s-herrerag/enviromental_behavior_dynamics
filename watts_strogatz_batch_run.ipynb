# %%
# More tests
import os
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import mesa

# Set a seed
np.random.seed(666)

# Plotting settings

from helpers import plot_all_agent_graphs
# Graphs font
plt.rcParams['font.family'] = 'Georgia'
color_dict = {
    'Anti - environment': 'orange',
    'Neutral': 'blue',
    'Pro - environment': 'green'
}

from model_statusgame import statusgame_model

alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="No", gamma=100, rho=1/3)
for i in range(300):
    alternative_game.step()

# Collect data
alternative_game_model = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
# Erdos-Renyi
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="erdos_renyi", p = 1/100, gamma = 100 ,rho=1/3)
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="erdos_renyi", p = 1/10, rho=1/3, gamma=100)
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
# Watts-Strogatz
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="watts_strogatz", p = 1/100, rho=1/3, gamma=100, k )
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="watts_strogatz", rho=2/3, gamma=100)
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="watts_strogatz", rho=1/3, gamma=100, k=30)
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="watts_strogatz", rho=3/4, gamma=100, k=30)
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
alternative_game = statusgame_model(N = 300, seed=666, lambda_s = 1, memory = 15, create_network="watts_strogatz", rho=1/3, gamma=300, k=50)
for i in range(100):
    alternative_game.step()

# Collect data
alternative_game_model_2 = alternative_game.datacollector.get_model_vars_dataframe() 
alternative_game_agents_2 = alternative_game.datacollector.get_agent_vars_dataframe().reset_index()
plot_all_agent_graphs(alternative_game_agents_2, color_dict, output_folder="test_1_creation", show_plots=True)

# %%
check = alternative_game_agents_2.loc[(alternative_game_agents_2.group.isin(["Neutral", "Pro - environment"])) & (alternative_game_agents_2.Step > 130)]
check.groupby("group").describe()
# Out:
# Empty DataFrame
# ...

# %%
alternative_game_agents_2
# Out:
#        Step  AgentID               group  avg_common     status  \
# 0         0        1             Neutral         NaN        NaN
# 1         0        2  Anti - environment         NaN        NaN
# 2         0        3             Neutral         NaN        NaN
# 3         0        4             Neutral         NaN        NaN
# 4         0        5  Anti - environment         NaN        NaN
# ...     ...      ...                 ...         ...        ...
# 30295   100      296   Pro - environment    2.600000  27.916667
# 30296   100      297   Pro - environment    2.263158  63.157895
# 30297   100      298   Pro - environment    2.500000  45.000000
# 30298   100      299   Pro - environment    2.000000  45.370370
# 30299   100      300  Anti - environment    1.875000  18.750000
#
#        field_of_action  consumption    utility   belief_min  belief_median  \
# 0                  NaN    38.817388        NaN          NaN            NaN
# ...

# %%
alternative_game_model_2
# Out:
#      dense_degree  connected_components  max_path_length  cluster_coefficient
# 0        4.140000                     1               13             0.389762
# 1        5.140000                     1                7             0.241968
# 2        6.140000                     1                6             0.164627
# 3        7.140000                     1                5             0.127500
# 4        8.140000                     1                5             0.101457
# ..            ...                   ...              ...                  ...
# 96      18.453333                     1                3             0.066865
# 97      18.446667                     1                3             0.065252
# 98      18.440000                     1                3             0.067733
# 99      18.433333                     1                3             0.067171
# 100     18.426667                     1                3             0.065733
#
# [101 rows x 4 columns]

# %%
agent7 = alternative_game_agents_2.loc[alternative_game_agents_2.AgentID == 7]

# %%
agent7
# Out:
#        Step  AgentID               group  avg_common     status  \
# 6         0        7  Anti - environment         NaN        NaN
# 306       1        7  Anti - environment    1.800000  40.000000
# 606       2        7  Anti - environment    1.666667  33.333333
# 906       3        7  Anti - environment    1.571429  21.428571
# 1206      4        7  Anti - environment    1.750000  33.333333
# ...     ...      ...                 ...         ...        ...
# 28806    96        7  Anti - environment    1.266667  13.333333
# 29106    97        7  Anti - environment    1.133333   6.666667
# 29406    98        7  Anti - environment    1.133333   6.666667
# 29706    99        7  Anti - environment    1.400000  13.333333
# 30006   100        7  Anti - environment    1.666667  23.333333
#
#        field_of_action  consumption    utility   belief_min  belief_median  \
# 6                  NaN    35.873019        NaN          NaN            NaN
# ...
