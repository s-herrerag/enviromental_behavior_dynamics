# %% [markdown]
# # Batch runs with $\gamma l$

# %%
# The tests are particularly interesting with Watts-Strogatz networks
import os
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import mesa

# Set a seed
np.random.seed(666)

# Plotting settings

from helpers import plot_all_agent_graphs
# Graphs font
plt.rcParams['font.family'] = 'Georgia'
color_dict = {
    'Anti - environment': 'orange',
    'Neutral': 'blue',
    'Pro - environment': 'green'
}

from model_statusgame import statusgame_model

# %%
params = {"seed": 666, 
          'N':[250],
          'lambda_s': [1], 
          "memory": [15], 
          "gamma": np.linspace(0, 2, 10), 
          "create_network": "watts_strogatz", 
          "k": [2, 5, 10, 15, 20], 
          "p": np.linspace(0, 1, 4),
          "rho": 1/3}

results_batch = mesa.batch_run(
    statusgame_model,
    parameters=params,
    iterations=5,
    max_steps=100,
    number_processes=None,
    #data_collection_period=100,  # Important, otherwise the datacollector will only collect data of the last time step
    display_progress=True,
)

results_batch_df = pd.DataFrame(results_batch)
results_batch_df.to_csv("results_batch_df_gammal.csv")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Process SpawnPoolWorker-8:
# Process SpawnPoolWorker-7:
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-5:
# Process SpawnPoolWorker-6:
# Process SpawnPoolWorker-4:
# Process SpawnPoolWorker-1:
# Process SpawnPoolWorker-2:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       1 params = {"seed": 666,
#       2           'N':[250],
#       3           'lambda_s': [1],
#    (...)
#       8           "p": np.linspace(0, 1, 4),
#       9           "rho": 1/3}
# ---> 11 results_batch = mesa.batch_run(
#      12     statusgame_model,
#      13     parameters=params,
#      14     iterations=5,
#      15     max_steps=100,
#      16     number_processes=None,
#      17     #data_collection_period=100,  # Important, otherwise the datacollector will only collect data of the last time step
#      18     display_progress=True,
#      19 )
#      21 results_batch_df = pd.DataFrame(results_batch)
#      22 results_batch_df.to_csv("results_batch_df_gammal.csv")
#
# File ~/anaconda3/lib/python3.11/site-packages/mesa/batchrunner.py:94, in batch_run(model_cls, parameters, number_processes, iterations, data_collection_period, max_steps, display_progress)
#      92 else:
#      93     with Pool(number_processes) as p:
# ---> 94         for data in p.imap_unordered(process_func, runs_list):
#      95             results.extend(data)
#      96             pbar.update()
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# Out:
# array([0.        , 0.22222222, 0.44444444, 0.66666667, 0.88888889,
#        1.11111111, 1.33333333, 1.55555556, 1.77777778, 2.        ])
